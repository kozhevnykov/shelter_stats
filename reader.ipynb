# %%
# голы по нику 

import os
folder = 'dataHAX/data/'


goals = 0
for filename in os.listdir(folder):
    f = os.path.join(folder, filename)
    row = 0
    with open(f, 'r', encoding='utf-8') as file:
        for line in file:
            row += 1
            if '⚽корж' in line and "Автогол" not in line: 
                #print(line, end="")
                goals += 1
print(goals)
# Out:
# 96

# %%
# list of names

import os
import re


folder = 'dataHAX/data/'

pattern = re.compile("^([A-Z][0-9]+)+$")
pattern.match("hey")

names = set()

for filename in os.listdir(folder):
    f = os.path.join(folder, filename)
    with open(f, 'r', encoding='utf-8') as file:
        for line in file:
            result = re.findall(r'⚽([^←]*)', line)
            if result:
                names.add(result[0].replace("\n","").strip())
print(len(names))
# Out:
# 1065

# %%
import re


pattern = re.compile("^.*⚽(.*)[\s←\s.*]?$")
print(pattern.match("30.09.2022 00:22:28.7 : 📢 : 🔵 Гол для синих! | 11:4 – 12:56 | ⚽пас не дал хуй соснул"))
# Out:
# <re.Match object; span=(0, 80), match='30.09.202:22:28.7 : 📢 : 🔵 Гол для синих! | 11:4 –>

# %%
result = re.findall(r'⚽([^←]*)', '29.09.2022 08:37:43.3 : 📢 : 🔵 Гол для синих! | 0:1 – 00:06 | Автогол | ⚽zxcursed ← gr0nback👟')
print (result)
# Out:
# ['zxcursed ']

# %%
# scores 

import os
folder = 'dataHAX/data/'
scores = {}

for name in names:
    goals = 0
    for filename in os.listdir(folder):
        f = os.path.join(folder, filename)
        row = 0
        with open(f, 'r', encoding='utf-8') as file:
            for line in file:
                row += 1
                if '⚽'+name in line and "Автогол" not in line: 
                    goals += 1
    ##if goals > 50:
    ##    print(name, goals)
    scores[name] = goals

#sorting of bombardis    
for k,v in sorted(scores.items(), key=lambda p:p[1], reverse=True):
    print(k,v)
# Out:
#  18202
# s 620
# 3oomer) 492
# R 467
# K 439
# Журналист 332
# e 315
# lfc 313
# fa 289
# fade 287
# УАрик 285
# extra 0 enjoyer 281
# Ted Lasso 274
# Шкарп 267
# pro0ch 264
# AzoT 251
# mali 250
# l1ch 232
# ХуТоРоК 214
# Amane Missa 206
# Tekashe 205
# Tekashe💙💛 205
# йо13 💙💛 198
# h 196
# Dorfixz 193
# Don Bass 189
# xXx 189
# so 187
# ChPoKvPuPoK 179
# Эстетика ануса 176
# Inzaghi 167
# tolyasik 161
# SNEG 156
# Roll 155
# FM | Tekashe 153
# Levi 150
# 69 150
# YR 144
# tara 138
# !Окей 135
# Шкарпетка 134
# moti 132
# Koldi_ 128
# zuu. 126
# gr0nback 125
# bababoy 125
# Піка 124
# la 124
# контрнаступ 124
# splaash 123
# Snack 120
# FCDK Vadi 119
# technoviking 115
# AzoT💙💛 115
# sprinkle 114
# RS14 108
# sonic 108
# mtz 107
# a 106
# Nigger 105
# mtzth 105
# корж 96
# M.Mudryk 93
# labeanchik 93
# jeQA | Od 93
# Khvicha Kvaratskhelia 92
# 7 91
# Техасский гуцул 88
# НЬЮ-ЙОРКСКАЯ ТРЕМБИТА 88
# riko 87
# !Okaq 87
# BLACKPINK 84
# Klipcrop 84
# vashp 84
# юра 84
# Швец. 82
# Sad_Bodya 82
# krot 81
# Levisssss 81
# (^^,) 80
# дерево 79
# H 77
# 1 77
# O 74
# а 74
# helio 73
# Gycь 73
# kris 71
# 11 70
# 111 69
# пес 69
# Toy 69
# Amane Missa ````````````` 68
# VampAthem 67
# W 67
# CaSkAdEr 67
# ME26DR87 64
# водяра 63
# Ок 63
# гілярович 63
# Mobley 61
# sinchiroca 61
# matv1ykoo 60
# zuu>3 57
# donhay 57
# hoW 57
# hooliegun 56
# Marlos 54
# Слава ЗСУ 54
# СоТиК 54
# Куп Люгерыч 53
# caskader 53
# Amane Misa 52
# Neymar 52
# Kaneki Ken 51
# SkriLL 50
# Аллистер 49
# WAG / DIAZ 49
# godbless 48
# Руналдо 48
# ivanyk_4 48
# Rollie 48
# 🅁🄰🄺 47
# . 47
# Vadi 47
# 3oomerq) 47
# ExS1nEeeZ 46
# Петро Щур 46
# soniq 46
# De Bruyne 45
# -daniklopik- 44
# Супер мамонтенок 43
# Шахтар Донецьк 43
# Oka 42
# XyToPoK 41
# Suarez 41
# Poop 39
# NoT 38
# Legend 💛 38
# Koldi_11 37
# хуторок 37
# МОЛЬФАР ИЗ КЕНТУККИ 36
# cop 36
# Д 35
# rak 35
# Glek 35
# Z 34
# tetsu 34
# Broadway182 33
# FreeZee 33
# Сало 32
# аянами рей 32
# H2O 32
# Denneriana 30
# KH|🤨MakaChu UA🇺🇦 30
# көтіңді айырамын 30
# paralet 30
# NEzzIL 30
# Floyse[Fake] 30
# Фоден 29
# ◟𝖇𝖆𝖘𝖙𝖆𝖗𝖉 𝖙𝖎𝖋𝖔◝ 29
# chpok 29
# FAFF 28
# Tchouameni 28
# fade\ 28
# бибек 27
# langschlange 27
# Miss 27
# nyar 26
# Bazyyka~\ 25
# Gyсь 25
# Бот 24
# Vya4ik 24
# Света инкубатор 24
# Скрег 24
# bird 24
# splaash' 24
# * 24
# Choji 23
# пон 23
# MCPetya 23
# Окa 23
# art 23
# Kaneki Ken. 22
# пушок 22
# Симметрия яичек 22
# Amane Misiiiiii 21
# Gejoza 21
# Vlynleyno 20
# Okaey 20
# tara qn 20
# пас не дал хуй соснул 20
# Носок 19
# cMoPoDoK 19
# Dez1ess 19
# extra  0 enjoyer 19
# ЧУМА 19
# ok 18
# Dot 18
# 8 18
# as1 18
# Mr.Penguin 18
# -goal 18
# акіп 18
# rak-fake 17
# VERMISHELLL 17
# Ghost Angel 17
# 𝖑𝖎𝖑 17
# Ghost 17
# Mask 17
# nk 17
# Lamborgini 17
# pushok 17
# Floyse{Fake} 16
# Вася 16
# NAzick 16
# sn1p 16
# Furia^^^Missa 16
# Nepler 16
# mArs 16
# dx 16
# cMoRoDo4Ka 15
# curu gainii 15
# Ян 15
# White people 15
# Okay 15
# бревно 15
# mordex 15
# merunis 15
# milkyworld  нуб 15
# видео 15
# दयालू व्यक्ति 15
# atom 14
# Можіт 14
# bobic 14
# bitter 14
# Сирник 14
# JABIEN 14
# superstar 14
# СЕЙВДУМИЩЕ 14
# Русские хуйня 14
# Furia^^^Missa Vamos 14
# arsenxiks 14
# 415 14
# Enner 13
# GównoZDupska 13
# zuu lupa 13
# AzeXc 13
# AM | Гій 13
# Ma1den 13
# klim 13
# geniy 13
# tetsu. 13
# DED 13
# SK|caskader 13
# artemhaxball 13
# *_DROGBA_* 13
# кетчуп 13
# Канеки 13
# bitterSweet 13
# msx 12
# music 12
# HUY 12
# solf 12
# Gabriel Jesus 12
# груша 11
# *-* 11
# your wife 11
# Talles Brener 11
# ПЛЕВРИТОВОЕ ДЫХАНИЕ 11
# Harinn 11
# глеб 11
# сейвдум 11
# Luka Modric 11
# x69pose 11
# Zack Steffen 11
# bane 11
# supernaut 11
# l1ch отец смородка 10
# зуу бlyat лох 10
# bolod 10
# Y.Sommer 10
# banek 10
# qwenty 10
# Cancelo 10
# нeІo 10
# castle 10
# bababoyq 10
# Robert 10
# chicken. 10
# -ebalosnoser 10
# анкара меси 10
# Valverde 10
# Okay! 10
# 🐷 10
# Лаваш 9
# GarikZp 9
# az0v 9
# Vitala 9
# st21 9
# ЗЕЛЯ 9
# АНАЛkonda 9
# 🏆 9
# Oleksandr 9
# dsb99 9
# Виталя онли вин 9
# toni 9
# Карандаш 9
# Robert Lewandowski 9
# Mi amas vin 9
# israel cyber 9
# galorka 8
# Сала 8
# Окей 8
# Buckethead 8
# Vladyslav Dubinchak 8
# :: 8
# MartinSK 8
# khvicha kvaratskhelia 8
# dlls 8
# Leo 8
# dixie 8
# GAGF 8
# f1la 8
# Oleksandr Vasyliev 8
# gh 8
# БАЙРАКТАРЧИК 8
# Tiberio 8
# Valett 8
# Karas 8
# zxcursed 8
# Amane Misa Shigetsu 7
# tara QN 7
# U U 7
# kenshi 7
# Gусь 7
# practice 7
# симонс 7
# Толик Вагина 7
# DrunkenNoob 7
# ℙℍ𝔸ℝ𝔸𝕆ℕ 7
# Skarp 7
# niger 7
# соу 7
# Антон 7
# Яна Члене Зумера 7
# кікі 7
# super_yarik00 7
# Din 7
# yanzoredd 7
# HIMARS 7
# клоп 7
# сливак 7
# dz 7
# who? 6
# ❌⭕❌⭕🎵 6
# kistyyxd) 6
# مالی 6
# Онанимка 6
# Legend#9 6
# Proxima 6
# Miss the rage 6
# belaciou 6
# экспрес дно 6
# Misixxx 6
# MISHAQ 6
# кракен 6
# Pacifistul 6
# Bernardo Silva 6
# Elizabeth II 6
# ждун 6
# gtne[ 6
# MPS #1 $$$ 5
# fade_ 5
# Axmet 5
# Петушара 5
# LExx 5
# Amane Missa 0 iq 5
# iSeb 5
# good 5
# Сашук Сергій 5
# 96 5
# Kenzo 5
# Josef 5
# mraz=vermishel 5
# Lega Nkabomga 5
# NICKNAME 5
# смысл 5
# Messi 5
# wsp 5
# iamberkankutlu 5
# Никогда не проигрывал 5
# Lucas Hernandez 5
# hhhh 5
# Kaka 5
# CS 5
# Gnabry 5
# сука меня пидр замутил пр 5
# Kody 5
# gleb 5
# ZXC||GT 5
# сіктім де, қол қойдым 5
# FreeM ;) 5
# Oleksiy Khakhlov 5
# Kai Havertz 5
# KO 5
# Vin.Junior 5
# Dе Bruyne 5
# ddips 5
# dfg 5
# YARMAK | UA 5
# okro 5
# полковник бустеренко 5
# egor_baranoeb 5
# TARA 5
# Liberty 5
# aurelian213 5
# diego forlan 5
# TheStriker 🏆 5
# kenshi17 5
# ᴷᴼᵀᴱᴴᴼᴷ 5
# Emp 5
# Skezzqa 5
# гадблесс повернувся 5
# d1a 5
# zolypka 4
# JACA PRACA 4
# Яне гретянка 4
# Artem Dovbyk 4
# Bandera 4
# dixiee 4
# Le_Mon 4
# Roller 4
# сальце 4
# Alpamys 4
# Rafael Toloi 4
# Masok 4
# Zaer 4
# Skam 4
# your mother 4
# POGO 🤍♥️ 4
# DimOne 4
# Haxi 4
# ST_|Memphis| 4
# Viva 4
# sebastian 4
# лох 4
# елокс 4
# Советский 4
# антоша 4
# toyboy 4
# жест доброй воли 4
# okrokhine 4
# Макіївський роднічок 4
# Vodafone 4
# Q 4
# Pedri 4
# kvicha kvartskhelia 4
# LifeCell 4
# MAW 4
# сала 4
# archie 4
# нолик 4
# mnky 4
# Zed 4
# і 4
# knopka 4
# Mitica 4
# PES PATRON 4
# Mest1k1ch 4
# pr0gamer 4
# lukifer 4
# ZашлиOтсосалиVышли 4
# riddoo[.] 4
# Alex 4
# Maryan Shved 4
# Saвеdyм 99 4
# spINKLE 4
# 𝚍𝚕𝚕𝚜 4
# Pitstop 4
# уц 4
# piNES 4
# Петро Биченок 4
# iy 4
# fd 4
# Студент. 4
# senia 4
# DaBaby 4
# Gamers799 4
# Iзюм⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ 4
# Дарук (daruk) 4
# Legan Kabomga 4
# ★oWn★ 4
# unionboys 4
# ИГАРЬ ПОБЕДИТЕЛЬ ЛЧ ХУЕПЕ 4
# Maxe3e4 4
# КРЭСС 4
# twojbober 4
# trowlll 4
# Персик 4
# ⠀⠀⠀⠀⠀⠀моргеншетрн⠀ 4
# HKane 4
# шлюха 4
# pipipop 4
# Louduanyu 4
# nekitxww 4
# Mam duży ping i chuja 4
# lutve 4
# extra admin enjoyer 3
# De breyne 3
# 𝓡𝓪𝓥𝓮𝓷 3
# Sou. 3
# Rashford™ 3
# N1MoLd 3
# Buschan 3
# лучшй 3
# Nathan Patterson 3
# нero 3
# Ojciec Flufeusz 3
# жінка тетсуі 3
# Jesus21 3
# Missa 3
# Ansu Fati 3
# Слава Героям Новороссии 3
# sairyyy 3
# FireFall 3
# Передоз 3
# Lilu 3
# dark 3
# Latina fucker 3
# Толик Вагинальный 3
# zuhn 3
# Leonardo Campana 3
# ккаеаукцук 3
# Frenkie de Jong 3
# Lotzy 3
# попа 3
# Puskarr 3
# Cuckold 3
# сейвдум228 3
# renty 3
# leroy 3
# олень 3
# я гей 3
# anus 3
# Михалич 3
# sᴋʀɪʟʟ 3
# kebab 3
# ярик 3
# TToStErNaK 3
# kot 3
# Od | jeQA 3
# africanu 3
# рома лох 3
# Мир во всем мире 3
# !Okaq 🐖 3
# pol 3
# Insigne 3
# ВОЛК 3
# sentyabr 3
# Мага 3
# СЕЙВДУМИЩЕ ЕБАЛ СОФОЧКУ 3
# Phumorist 3
# хуйбек 3
# продавец арбузов 3
# slyvka pups 3
# mishaq 3
# wert 3
# НА ДАХУ Я 3
# днр лнр 3
# Maks Luburic 3
# kienši 3
# 🎅Sheva🎅 3
# kiki🎁🎁🎁 3
# Я роблю домашку (Руналдо) 3
# lanschlange 3
# Super_yarik00 3
# превентивный удар 3
# zoro 3
# СЛАВА УКРАЇНІ!! 3
# bimba2 1
# dedincaid 1
# antadr 1
# пупка 1
# preston presti 1
# Altay Bayındır 1
# :} 1
# GarikZP 1
# lunatiq 1
# EBANAT 1
# LeoGar 1
# Taco Hemingway 1
# Horoshuy 1
# Azik 1
# trung<3c.. 1
# 1233 1
# M1XaL 1
# Goiaba 0
# Sporar 0
# dima_newi 0
# Zack Steffen(v)|GK 0
# dlls ёпта 0
# ukraine 0
# Вирджил ван Дейк 0
# Q.Long 0
# Bankia 0
# trapmath 0
# NovA 0
# WE LOVE UKRAINA 0
# vtyz pjden rerb 0
# _pausE 0
# bebrochka 0
# nsisk 0
# Kvaratskhelia 0
# salvio 0
# Chadmilian I 0
# Mirzayev 0
# я  трахаю сплеш 0
# JeQA Od 0
# тетса 0
# соник бот 0
# [GK] Kaiju 0
# донбасс это россия 0
# SyWs|P.R.I.Z.R.A.K. 0
# arestovich 0
# WEGHORST 0
# ☭ 0
# Onana 0
# Luka Modrić|MC 0
# sirius 0
# 27.09 0
# Нигер 0
# Mendy💛💙 0
# ke3o 0
# bueno 0
# 22 0
# arniuxinas 0
# kkk 0
# 𝒮𝒪𝐹𝒪𝒱𝐼𝒞𝐻 0
# Lewis O`Brien 0
# вася цан 0
# jaecu 0
# Virgil 0
# Polaczek 0
# basur yavaş 0
# Lyndon Dykes 0
# † 𝚆𝚒𝙻𝚂𝚘𝙽 † 0
# puro s2ci 0
# Crespo 0
# zina17 0
# dasha 0
# сr1stall 0
# hortik 0
# 12333333 0
# ССУ В РОТ МАТЕРИ ДЫХАНИЯ 0
# MHD 0
# Fati 0
# Nako 0
# lol 0
# janurz 0
# srry 0
# karas#8513 0
# Белий негр 0
# yes 0
# лмао 0
# Baller 0
# Tudor geiming 0
# ilyasik 0
# 56456 0
# OK 0
# depay 0
# zxc bodya 0
# donbass = russia 0
# de gea 0
# ,kznm vtyz pjden gbpley 0
# listek 0
# Killernik 0
# Future_ 0
# bebra 0
# Kherson 0
# xiadness 0
# бомж 0
# atom1k 0
# Lix 0
# Lil_PiP 0
# harry maguire 0
# Шелбин 0
# Dimooon 0
# mafios 0
# ODS 0
# holik 0
# Kevin De Bruyne 0
# pisag 0
# игнатюк 0
# Hinzik 0
# sdf 0
# Mendy💙💛 0
# НОРМАЛЬНОЕ ДЫХАНИЕ 0
# criminal 0
# HarryMaguire 0
# KKQQ 0
# 🎅Scheva🎅 0
# Доброволец ЛНР 0
# ей сучка 0
# chwerty 0
# санс 0
# extra 1 enjoyer 0
# бэмби 0
# Kirek 0
# 1000-7 l UA 0
# Буфонищееее 0
# :> 0
# Ceh9 0
# RoM4iK SmAiLiK (UA) 0
# mapiston 0
# arf1nho 0
# члвековк 0
# АльцGamer 0
# .MAKSALDINI. 0
# lODERN 0
# alexandra 0
# Slimani 0
# харьков это россия 0
# czarny 0
# sterling 0
# shaparenko 0
# Супчик Maggi 0
# Newplayer 0
# Cloud Spirit 0
# UA Cloud 0
# bober 0
# бабєбер 0
# Katsu 0
# Marcelo 0
# чак норрес 0
# v4 0
# printer 0
# НИКИМА 0
# мутяра 0
# жекіч 0
# jjjj 0
# Metro 0
# носочек 0
# 544 0
# Putin is 170px tall 0
